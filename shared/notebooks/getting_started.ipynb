# %% [markdown]
# # Analytical Ecosystem - Getting Started
#
# This notebook demonstrates how to connect to the various services in the ecosystem.

# %% [markdown]
# ## PostgreSQL Connection
#
# If you have PostgreSQL running (`--profile postgres`), you can connect like this:

# %%
# Load SQL magic
# %load_ext sql

# Connect to PostgreSQL
# %sql postgresql://analyticsUser:analyticsPass@postgres:5432/analytics

# %%
# Run a query
# %sql SELECT version();

# %% [markdown]
# ## Elasticsearch Connection
#
# If you have Elasticsearch running (`--profile elasticsearch`):

# %%
from elasticsearch import Elasticsearch

# Connect to Elasticsearch
es = Elasticsearch("http://elasticsearch:9200")

# Check cluster health
es.info()

# %% [markdown]
# ## Redis Connection
#
# If you have Redis running (`--profile redis`):

# %%
import redis

# Connect to Redis
r = redis.Redis(host='redis', port=6379, decode_responses=True)

# Test connection
r.ping()

# %% [markdown]
# ## Working with DAGs
#
# The `/home/jovyan/work/dags` directory is shared with Airflow. Any DAGs you create here will be picked up by Airflow!

# %%
import os

# List DAGs in the shared directory
dags_dir = '/home/jovyan/work/dags'
print("Available DAGs:")
for f in os.listdir(dags_dir):
    if f.endswith('.py'):
        print(f"  - {f}")
